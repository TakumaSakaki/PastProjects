# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
plt.style.use("ggplot")
# %matplotlib inline

# %%
def get_data(test_or_train):
    flag = True
    for target_digit in np.arange(10):
        if (flag):
            x = np.array(pd.read_csv("digit/digit_" + test_or_train + str(target_digit) + ".csv", header = None))
            y = np.ones(len(x)) * target_digit
            flag = False
        else:
            tmp = np.array(pd.read_csv("digit/digit_" + test_or_train + str(target_digit) + ".csv", header = None))
            tmp_y = np.ones(len(tmp)) * target_digit
            x = np.concatenate([x, tmp])
            y = np.concatenate([y, tmp_y])
            
    return x, y

# %%
def calc_K(x1,x2, h):
    return np.exp(-(np.linalg.norm(x1 - x2, ord=2) ** 2)/(2* (h ** 2)))

def K_matrix(x, y, h):
    return np.array([calc_K(i,j,h) for i in x for j in y]).reshape(len(x),len(y))

# %%
class GaussianKernelL2Regression:
    
    def __init__(self, K, _lambda = 0.1, h = 1):
        self.K = K
        self._lambda = _lambda
        self.h = h

    def fit(self, X, y):
        self.X = X
        self.theta = np.matmul(np.matmul(np.linalg.inv(np.matmul(self.K, self.K) + self._lambda * np.eye(len(X))), self.K),y)
        
    def predict(self, predict_K):
        return np.matmul(predict_K, self.theta)

# %%
#データの取得
train_X, train_y = get_data("train")
test_X, test_y = get_data("test")

#カーネル行列を事前に計算しておく
K = K_matrix(train_X, train_X, 1)
predict_K = K_matrix(test_X, train_X, 1)

#学習（一対他法）
models = []
for i in tqdm(np.arange(10)):
    y = np.array([1 if a == i else -1 for a in train_y])
    model = GaussianKernelL2Regression(K)
    model.fit(train_X, y)
    models.append(model)
# Out:
# 100%|██████████| 10/10 [02:26<00:00, 14.11s/it]

# %%
#予測
ys = np.empty([10, len(test_y)])
for i in tqdm(np.arange(10)):
    ys[i] = models[i].predict(predict_K)

#最大スコアをもつクラスに分類する
y = np.argmax(ys, axis=0)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 126.06it/s]

# %%
#結果
result_matrix = pd.crosstab(test_y, y, margins=True)
print("Total accuracy :", np.diag(result_matrix.values[:-1, :-1]).sum() / result_matrix.values[-1,-1])
result_matrix.style.background_gradient(cmap = "Reds")
# Out:
# Total accuracy : 0.965
# <style  type="text/css" >
#     #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col0 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow0_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col1 {
#             background-color:  #69000d;
#             color:  #f1f1f1;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow1_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col2 {
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col7 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col8 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col9 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow2_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col3 {
#             background-color:  #7e0610;
#             color:  #f1f1f1;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col5 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col7 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col8 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col9 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow3_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col4 {
#             background-color:  #73030f;
#             color:  #f1f1f1;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col5 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col6 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col9 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow4_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow5_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow5_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow5_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_188db480_76b9_11e9_b048_4c3275896f4brow5_col4 {
#             background-color:  #fff5f0;
#             color:  #000000
